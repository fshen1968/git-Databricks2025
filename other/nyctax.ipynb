# %%
#cp -r /databricks-datasets/songs/data-002/ /Volumes/main/songs/data-002/

# %%
# %sql
SELECT * FROM samples.nyctaxi.trips LIMIT 10

# %%
display(dbutils.fs.ls('/databricks-datasets/songs'))

# %%
# %fs
ls /databricks-datasets/
